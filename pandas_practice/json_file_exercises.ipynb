# %%
import pandas as pd
import json

# %%
with open('data/18_5_2021.json') as data_file:
    data = data_file.read()
    #print(data)
    #print(type(data)) It's a str at this point

    data_content = json.loads(data) # Becomes a dict
  
data_content["log"][490] # Sample access
# Out:
# {'12:15:16': [{'Linux Gaming': []},
#   {'General Comms': [{'johann': '396397812037713924'},
#     {'Liam ¬ LTF': '716047297636597782'},
#     {'24nico': '135957433095815169'},
#     {'ygg_anderson': '659828514924658688'},
#     {'BK': '708865402943438929'},
#     {'Aidan | LTF': '686755249138302977'},
#     {'🐙 octopus': '699811072282066945'},
#     {'SweptbackCat': '620632911498182675'}]},
#   {'Algo Trading': []},
#   {'Private Meetings': []},
#   {'Token Engineering': []},
#   {'Development': []},
#   {'Solarpunk': []}]}

# %%
print(type(data_content))
# Out:
# <class 'dict'>

# %%
data_content["log"]
# Out:
# [{'0:0:9': [{'Linux Gaming': []},
#    {'General Comms': []},
#    {'Algo Trading': []},
#    {'Private Meetings': []},
#    {'Token Engineering': []},
#    {'Development': []},
#    {'Solarpunk': []}]},
#  {'0:1:39': [{'Linux Gaming': []},
#    {'General Comms': []},
#    {'Algo Trading': []},
#    {'Private Meetings': []},
#    {'Token Engineering': []},
#    {'Development': []},
#    {'Solarpunk': []}]},
#  {'0:3:9': [{'Linux Gaming': []},
#    {'General Comms': []},
#    {'Algo Trading': []},
#    {'Private Meetings': []},
#    {'Token Engineering': []},
#    {'Development': []},
#    {'Solarpunk': []}]},
#  {'0:4:39': [{'Linux Gaming': []},
#    {'General Comms': []},
#    {'Algo Trading': []},
#    {'Private Meetings': []},
#    {'Token Engineering': []},
#    {'Development': []},
#    {'Solarpunk': []}]},
#  {'0:6:9': [{'Linux Gaming': []},
#    {'General Comms': []},
#    {'Algo Trading': []},
#    {'Private Meetings': []},
#    {'Token Engineering': []},
# ...
